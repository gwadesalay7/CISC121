# %% [markdown]
# # CISC 121 – Assignment-1
#
# ## 🔗 Problem
# Fizz Buzz – https://leetcode.com/problems/fizz-buzz/
#
# Palindrome Number – https://leetcode.com/problems/palindrome-number/
#
# Reverse Integer – https://leetcode.com/problems/reverse-integer/
#
# Two Sum – https://leetcode.com/problems/two-sum/
#
# Valid Palindrome – https://leetcode.com/problems/valid-palindrome/

# %% [markdown]
# #  Problem 1

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# _Understand the problem, inputs/outputs, constraints, and  write down your plan or steps to solve the problem or draw the flowchart using digital or real pen-paper. Insert the image._
#
# **AI Level 1** is allowed to understand the concept, but you need to sketch the problem down by yourself.
#
# **Your effort is more important than the accuracy for this section**

# %% [markdown]
# I have included a screenshot of my understanding and breakdown to the first problem here:
#
# ![fizzBuzz1.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# Visit the **"Solutions"** tab on LeetCode for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# ### **Example Answer (for "Palindrome Number"):**
#
# I reviewed the top solution under the LeetCode “Solutions” tab and one post on Stack Overflow:
# https://stackoverflow.com/questions/17129222/how-to-check-if-a-number-is-palindrome-in-python
#
# I learned that I can reverse the integer using a loop with modulo and division instead of converting it to a string. Using this idea, I tried writing a function that reverses the number and compares it to the original.

# %%
# Your draft code here (does not need to be fully correct)

# Griffin Wade-Salay (20260208)
# I looked at a few examples and they used a for loop with if/elif/else
# statements nested inside. I used this same format for my code. As well,
# they used the modulo operator which is useful when asking if certain values
# can be divided cleanly by other ones.

import numpy

result = []
n = int(input("Enter an integer that is greater than 1"))
for i in range(1, n+1):
  if i % 3 == 0:
    result.append("Fizz")
  elif i % 5 == 0:
    result.append("Buzz")
  elif i % 3 == 0 and i % 5 == 0:
    result.append("FizzBuzz")
  else:
    result.append(i)

print(f"Here is the list: {result}")

# I have started using f-formatted strings in python which is relatively new
# It involves using 'f' at the beginning and using {} for variables without
# breaking the quotes
# In my opinion, it is easier than going "text" + variable + "text"
# Out:
# Enter an integer that is greater than 110
# Here is the list: [1, 2, 'Fizz', 4, 'Buzz', 'Fizz', 7, 8, 'Fizz', 'Buzz']

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
# Final working solution - I added some proofing against incorrect inputs like a string or an integer that is less than 1.
# AI DISCLAIMER: I used Gemini 2.5 for wisdom about how to use try/except properly, and the use of "ValueError" to identify an incorrect data type input.

result = []
try:
  n = int(input("Enter an integer that is greater than or equal to 1: "))  #input
  if n >= 1:
    for i in range(1, n+1):  # iterating through the range of numbers (n+1 so that it includes the endpoint of n)
      if i % 3 == 0 and i % 5 != 0:
        result.append("Fizz")
      elif i % 5 == 0 and i % 3 != 0:  #conditional statements
        result.append("Buzz")
      elif i % 3 == 0 and i % 5 == 0:
        result.append("FizzBuzz")
      else:
        result.append(str(i))  # if none, just append the number
    print(f"Here is the list: {result}")
  if n < 1:
    print("Please insert an integer that is greater than or equal to 1.")  #print messages
except ValueError:
  print("Please insert an integer!")
# Out:
# Enter an integer that is greater than or equal to 1: 55
# Here is the list: ['1', '2', 'Fizz', '4', 'Buzz', 'Fizz', '7', '8', 'Fizz', 'Buzz', '11', 'Fizz', '13', '14', 'FizzBuzz', '16', '17', 'Fizz', '19', 'Buzz', 'Fizz', '22', '23', 'Fizz', 'Buzz', '26', 'Fizz', '28', '29', 'FizzBuzz', '31', '32', 'Fizz', '34', 'Buzz', 'Fizz', '37', '38', 'Fizz', 'Buzz', '41', 'Fizz', '43', '44', 'FizzBuzz', '46', '47', 'Fizz', '49', 'Buzz', 'Fizz', '52', '53', 'Fizz', 'Buzz']

# %% [markdown]
# Add the screenshot of output for all the test cases from your working solutions.

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: Conditional logic was not quite correct: because "Buzz" was first, it would say "Buzz" for numbers that were divisible by both 3 and 5 (Fizzbuzz)

# Draft code

for i in range(1, n+1):
  if i % 3 == 0:
    result.append("Fizz")
  elif i % 5 == 0:
    result.append("Buzz")
  elif i % 3 == 0 and i % 5 == 0:
    result.append("FizzBuzz")

#Fixed/final version - added more specification to each condition, by adding != statements, there was no longer any ambiguity.

for i in range(1, n+1):
  if i % 3 == 0 and i % 5 != 0:
    result.append("Fizz")
  elif i % 5 == 0 and i % 3 != 0:
    result.append("Buzz")
  elif i % 3 == 0 and i % 5 == 0:
    result.append("FizzBuzz")

# %%
# Fix 2: Added safeguards against wrong inputs

# Draft version: No safeguards

# Fixed version: Avoids errors/crashes due to safeguards

try:
  n = int(input("Enter an integer that is greater than or equal to 1: "))
  if n < 1:
    print("Please insert an integer that is greater than or equal to 1.") #making sure n is an integer of 1 or greater
except ValueError:
  print("Please insert an integer!") #making sure n is an integer

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# 1. In general, I came up with this code myself - I thought about my own experience using lists and for loops and thought that that would be the best course of action for this application.
#
# 2. AI helped with small things, like properly formatting functions and operators that I don't really use or have never used before (in the case of try and except)
#
# 3. Complete answers on leetcode to the problem were also useful, as they helped me make the code more efficient. That being said, I didn't use a function (def fizzBuzz) because I am still not super clear on how functions work and I would like to fully understand everything in my code.

# %% [markdown]
# #  Repeat this template for Problems 2–5
# You may copy-paste the above section 4 more times or duplicate cells in your notebook environment.
#
# Remember:
# Proper attribution
# No copy-pasting from AI or others

# %% [markdown]
# #  Problem 2 - Palindrome Number

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# _Understand the problem, inputs/outputs, constraints, and  write down your plan or steps to solve the problem or draw the flowchart using digital or real pen-paper. Insert the image._
#
# **AI Level 1** is allowed to understand the concept, but you need to sketch the problem down by yourself.
#
# **Your effort is more important than the accuracy for this section**

# %% [markdown]
# I have included a screenshot of my understanding and breakdown to the second problem here:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# Visit the **"Solutions"** tab on LeetCode for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# ### **Example Answer (for "Palindrome Number"):**
#
# I reviewed the top solution under the LeetCode “Solutions” tab and one post on Stack Overflow:
# https://stackoverflow.com/questions/17129222/how-to-check-if-a-number-is-palindrome-in-python
#
# I learned that I can reverse the integer using a loop with modulo and division instead of converting it to a string. Using this idea, I tried writing a function that reverses the number and compares it to the original.

# %%
# Your draft code here (does not need to be fully correct)

# Griffin Wade-Salay (20260208)

# I know the above answer was an example answer, but I did learn through leetcode answer that I can reverse the integer using modulo and division which seems cleaner
# than converting it to a string so I attemped to write the code based on that method as opposed to converting it to a string.

def palindrome(n):
  n = int(input("Please input an integer"))
  reverse = 0
  while n != 0:
    reverse = reverse * 10 + n % 10  #Creating the reverse numbers
    n = n // 10

  if n == reverse:
    print(f"The integer {n} is a palindrome!")
  else:
    print(f"The integer {n} is not a palindrome.") #Printing true/false conditions

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
# Final working solution
# AI DISCLAIMER: I used Gemini 2.5 for advice about how to correctly use functions and call them. One of the changes it suggested is to do the input outside of the function.
# Another bit of help I got from Gemini 2.5 is to use a try/except statement, acting as an efficient way to structure the main code executable

import sys

def palindrome(n):
  inNum = n
  reverseNum = 0

  if n < 0:
    sys.exit("Negative numbers cannot be palindromes!") # I was reading about the sys module and decided to incorporate sys.exit if it's a negative number

  while n != 0:
    lastDigit = n % 10 #Decided to break this up into another step because I found it kind of confusing otherwise. This step gets the last digit of the original number
    reverseNum = reverseNum * 10 + lastDigit  #This attaches the last digit onto the reverse number. For the 1st iteration, it is simply the last digit of the orig. number
    n = n // 10 #This becomes zero and thus breaks the while loop when the number is fully reversed (same # of iterations as there are digits)

  if inNum == reverseNum:
    print(f"The integer {inNum} is a palindrome!")
  else:
    print(f"The integer {inNum} is not a palindrome.") #Printing true/false conditions


try:
  inNum = int(input("Please enter an integer: "))
  palindrome(inNum) # Calling the function with the user-inputted value
except ValueError:
  print("Error - Please input an integer")
# Out:
# Please enter an integer: 676
# The integer 676 is a palindrome!

# %% [markdown]
# Add the screenshot of output for all the test cases from your working solutions.

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: Placement of the function and how I called and setup the function. Draft code shows the input inside of the function which doesn't really make sense - the parameter
# would just get overwritten by the input. Instead, I called the function after it had already been created.

# Draft code

def palindrome(n):
  n = int(input("Please input an integer"))
  reverse = 0
  while n != 0:
    reverse = reverse * 10 + n % 10  #Creating the reverse numbers
    n = n // 10


#Fixed/final version - built the function outside of the executing code - also added essential variables like holding n as inNum.

def palindrome(n):
  inNum = n
  reverseNum = 0
  if n < 0:
    sys.exit("Negative numbers cannot be palindromes!")
  while n != 0:
    lastDigit = n % 10
    reverseNum = reverseNum * 10 + lastDigit
    n = n // 10
  if inNum == reverseNum:
    print(f"The integer {inNum} is a palindrome!")
  else:
    print(f"The integer {inNum} is not a palindrome.")

# %%
# Fix 2: Fixed logic regarding the actual reversing process. Added an extra step (lastDigit) which made it less immune to potential errors and confusion

# Draft version:

while n != 0:
  reverse = reverse * 10 + n % 10
  n = n // 10

# Fixed version:

while n != 0:
  lastDigit = n % 10 #Decided to break this up into another step because I found it kind of confusing otherwise. This step gets the last digit of the original number
  reverseNum = reverseNum * 10 + lastDigit
  n = n // 10

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# 1. I was going to accomplish this problem by converting it to a string and using slicing but this more mathematical way that I found out from leetcode answers proved to be more elegant.
#
# 2. AI helped with helping me understand the process of how I can reverse numbers using this method by providing step by step explanations.
#
# 3. That being said, I still completed and formatted the code myself - I'm sure there is a more efficient way of doing it but I am still learning.

# %% [markdown]
# #  Problem 3 - Reverse Integer

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# _Understand the problem, inputs/outputs, constraints, and  write down your plan or steps to solve the problem or draw the flowchart using digital or real pen-paper. Insert the image._
#
# **AI Level 1** is allowed to understand the concept, but you need to sketch the problem down by yourself.
#
# **Your effort is more important than the accuracy for this section**

# %% [markdown]
# I have included a screenshot of my understanding and breakdown to the third problem here:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# Visit the **"Solutions"** tab on LeetCode for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# ### **Example Answer (for "Palindrome Number"):**
#
# I reviewed the top solution under the LeetCode “Solutions” tab and one post on Stack Overflow:
# https://stackoverflow.com/questions/17129222/how-to-check-if-a-number-is-palindrome-in-python
#
# I learned that I can reverse the integer using a loop with modulo and division instead of converting it to a string. Using this idea, I tried writing a function that reverses the number and compares it to the original.

# %%
# Your draft code here (does not need to be fully correct)

# Griffin Wade-Salay (20260208)

# I used a very similar process (using modulo and floor division) to accomplish the reverse value, the same way the solution I found on leetcode accomplished this problem.
# I also learned that I should put the 32-bit restriction on the reverse number in the while loop calculating the reverse number from the leetcode solution - as the way I
# was trying it at first was not working. I still have not figured out how to accommodate negative values and dropping the 0 from the reverse of numbers that end with 0
# (e.g., 650 --> 56, NOT 056). This will be fixed in the working code section below.

def reverse_integer(x):
  reverse = 0
  if x < -2**31 or x > 2**31 - 1:
    print("Failed: 64-bit integer or higher not supported")
    return False
  else:
    while x != 0:
      lastDigit = x % 10
      reverse = reverse * 10 + lastDigit
      x = x // 10
      if reverse < -2**31 or reverse > 2**31 - 1:
        print("Failed: 64-bit integer or higher not supported")
        return False


  print(f"{reverse} is your number, reversed!")

try:
  userInput = int(input("Input an integer"))
  reverse_integer(userInput)
except ValueError:
  print("Error - input must be an integer")
# Out:
# Input an integer1247247241
# 1427427421 is your number, reversed!

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
# Final working solution - It turns out that it automatically deals with integers that have a zero at the end. Thus, 650 becomes 56 automatically - no code needed.
# AI DISCLAIMER: Used Gemini 2.5 to help figure out the best way of avoiding negative values in the calculation but still adding the negative sign to the reversed value after
# the fact.

def reverse_integer(x):

  reverse = 0
  sign = -1 if x < 0 else 1  #Dealing with potential negative numbers
  x = abs(x)

  if x < -2**31 or x > 2**31 - 1:
    print("Error - 64 bit integer or higher not accepted")
    return False
  else:
    while x != 0:
      lastDigit = x % 10
      reverse = reverse * 10 + lastDigit   #reversing the numbers
      x = x // 10
      if reverse < -2**31 or reverse > 2**31 - 1:   #constraint check for reversed number
        print(int(0))
        return False


  reverse = sign * reverse #adding back the negative sign if input was negative
  print(f"{reverse} is your number, reversed!")

try:
  userInput = int(input("Input an integer"))   #execution of the function
  reverse_integer(userInput)
except ValueError:
  print("Error - input must be an integer")
# Out:
# Input an integer-1111111119
# 0

# %% [markdown]
# Add the screenshot of output for all the test cases from your working solutions.

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: Program could not deal with negative input integers. By adding a new variable called 'sign', it stored the sign of the input integer which could then be multiplied
# to the reversed number after the fact, keeping the original sign. Thus, -134 --> -431

# Draft code

def reverse_integer(x):
  reverse = 0
  if x < -2**31 or x > 2**31 - 1:
    print("Failed: 64-bit integer or higher not supported")
    return False
  else:
    while x != 0:
      lastDigit = x % 10
      reverse = reverse * 10 + lastDigit
      x = x // 10
      if reverse < -2**31 or reverse > 2**31 - 1:
        print("Failed: 64-bit integer or higher not supported")
        return False

#Fixed/final version - added the sign variable, made x abs() which made it functional in the reverse process, then afterwards multiplied reverse by the sign variable

def reverse_integer(x):

  reverse = 0
  sign = -1 if x < 0 else 1  #Dealing with potential negative numbers
  x = abs(x)

  if x < -2**31 or x > 2**31 - 1:
    print("Error - 64 bit integer or higher not accepted")
    return False
  else:
    while x != 0:
      lastDigit = x % 10
      reverse = reverse * 10 + lastDigit
      x = x // 10
      if reverse < -2**31 or reverse > 2**31 - 1:
        print(int(0))
        return False


  reverse = sign * reverse #adding back the negative sign if input was negative

# %%
# Fix 2: Had to reread the problem description - if the reverse number was over 32 bit limit, return a '0' instead of an error message. Fixed this.

# Draft version: Returned an error message

if reverse < -2**31 or reverse > 2**31 - 1:
  print("Failed: 64-bit integer or higher not supported")
  return False

# Fixed version: Returned '0'

if reverse < -2**31 or reverse > 2**31 - 1:
  print(int(0))
  return False

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# 1. This was a more challenging problem, and AI definitely helped with the idea of creating a separate variable to store the sign of the input integer. I didn't think of that, but I did think of making the input abs() in order to bypass the negative value errors with the reversal math.
#
# 2. Answers on leetcode confirmed that the modulo/division method for reversing values was a viable one and perhaps more elegant than slicing up strings.
#
# 3. I am starting to understand how to properly use and call functions now, thanks to getting help from web searches and using AI to debug my function syntax occasionally.

# %% [markdown]
# #  Problem 4 - Two Sum

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# _Understand the problem, inputs/outputs, constraints, and  write down your plan or steps to solve the problem or draw the flowchart using digital or real pen-paper. Insert the image._
#
# **AI Level 1** is allowed to understand the concept, but you need to sketch the problem down by yourself.
#
# **Your effort is more important than the accuracy for this section**

# %% [markdown]
# I have included a screenshot of my breakdown and understanding to problem 4 (two sum) here (NO AI USED IN THIS SECTION): ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# Visit the **"Solutions"** tab on LeetCode for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# ### **Example Answer (for "Palindrome Number"):**
#
# I reviewed the top solution under the LeetCode “Solutions” tab and one post on Stack Overflow:
# https://stackoverflow.com/questions/17129222/how-to-check-if-a-number-is-palindrome-in-python
#
# I learned that I can reverse the integer using a loop with modulo and division instead of converting it to a string. Using this idea, I tried writing a function that reverses the number and compares it to the original.

# %%
# Your draft code here (does not need to be fully correct)

# Griffin Wade-Salay (20260208)

# This was a method proposed by a solution on leetcode (to brute force it using two ranges). This code does not work, however, and I will be trying to diagnose the problems
# to make code that works in the final code section. Maybe a different method is required. The answer said something about using hash tables but I am not familiar with what
# a hash table is.

def two_sum(ints: list[int], target: int):
  list_length = len(ints)
  for i in range(list_length - 1):  #[0] to the second last indice
    for j in range(i + 1, list_length): #[1] to the last indice
      if ints[i] + ints[j] == target:
        print([i, j])

try:
  input_list = input("Input a list of integers")
  input_target = input("Input a target integer")
  two_sum(input_list, input_target)
except ValueError:
  print("Wrong input form.")
# Out:
# Input a list of integers[1, 2, 3, 4]
# Input a target integer7

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
# Final Code | Griffin Wade-Salay (20260208)
# AI (ChatGPT) was used to help me use a hash table {} to complete this problem with greater efficiency and also solve some bug fixes. In addition, using new (for me) python
# lexicon such as "raise", formatting an input as a list of integers in a clean way, and checking for input constraints by using the all() function.

def two_sum(nums: list[int], target: int):
  valid_range = range(-10**9, 10**9 + 1) #These are the constraints
  valid_length = range(2, 10**4 + 1)
  num_dict = {} # Empty hash table/dict

  if not all(n in valid_range for n in nums) or target not in valid_range:  #Checking for first two constraints
    raise ValueError("One or more input numbers exceed valid ranges.")

  if len(nums) not in valid_length:  #Checking for third constraint
    raise ValueError("List length is too short or too long.")

  for i, num in enumerate(nums):  #Using enumerate to iterate through the input list, returning both index and value (creating a hash table)
    num_two = target - num  #logic for determining the second number to equal the target

    if num_two in num_dict:  #Returning indices that satisfy the two sum condition
      return [num_dict[num_two], i]
      print(num_dict[num_two], i)

    num_dict[num] = i  #Storing the index in the hash table if initial two sum iteration unsuccessful
  return("No two sum solution.")

input_nums = list(map(int, input("Please input a list of space-separated integers.").split())) #Inputs
input_target = int(input("Please input a target number."))
two_sum(input_nums, input_target) #call function
# Out:
# Please input a list of space-separated integers.1 4 7 9
# Please input a target number.16
# [2, 3]

# %% [markdown]
# Add the screenshot of output for all the test cases from your working solutions.

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: Fixed the overall method of how the code functioned: went from brute forcing the selection to using a hash table {}. This reduces the time complexity and thus
# makes the process more efficient. Enumerate() was used to retreive the index and the value which made the process much easier and tested it with simple logic.

# Draft code - This was doing 2 iterations of a range

def two_sum(ints: list[int], target: int):
  list_length = len(ints)
  for i in range(list_length - 1):  #[0] to the second last indice
    for j in range(i + 1, list_length): #[1] to the last indice
      if ints[i] + ints[j] == target:
        print([i, j])

#Fixed version:

def two_sum(ints: list[int], target: int):
  num_dict = {} # Empty hash table/dict

  for i, num in enumerate(nums):  #Using enumerate to iterate through the input list, returning both index and value (creating a hash table)
      num_two = target - num  #logic for determining the second number to equal the target

      if num_two in num_dict:  #Returning indices that satisfy the two sum condition
        return [num_dict[num_two], i]
        print(num_dict[num_two], i)

      num_dict[num] = i  #Storing the index in the hash table if initial two sum iteration unsuccessful
    return("No two sum solution.")

# %%
# Fix 2: Had to reread the problem description - Implemented constraints

# Draft version: No constraints were added

# Fixed version: Added a method of dealing with constraints on the inputs

def two_sum(nums: list[int], target: int):
  valid_range = range(-10**9, 10**9 + 1) #These are the constraints
  valid_length = range(2, 10**4 + 1)

  if not all(n in valid_range for n in nums) or target not in valid_range:  #Checking for first two constraints
    raise ValueError("One or more input numbers exceed valid ranges.")

  if len(nums) not in valid_length:  #Checking for third constraint
    raise ValueError("List length is too short or too long.")

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# 1. This was the most challenging problem so far and I tried to use other's code and AI to help. The answers on leetcode also suggested using a hash table as one of the methods but the answers I looked at didn't work and resulted in difficult to diagnose errors.
#
# 2. AI (ChatGPT) was very helpful for me to better understand and write functional code for this problem. I got it to explain to me in detail how hash tables worked and the best way of implementing them, decreasing complexity.
#
# 3. I contributed the constraint part and the overall formatting of the code, plus the logic that led to the backbone of the two sum process. I decided to use raise errors if the inputs did not meet the constraints.

# %% [markdown]
# #  Problem 5 - Valid Palindrome

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# _Understand the problem, inputs/outputs, constraints, and  write down your plan or steps to solve the problem or draw the flowchart using digital or real pen-paper. Insert the image._
#
# **AI Level 1** is allowed to understand the concept, but you need to sketch the problem down by yourself.
#
# **Your effort is more important than the accuracy for this section**

# %% [markdown]
# I have included a screenshot of my breakdown and understanding to problem 5 (valid palindrome) here (NO AI USED IN THIS SECTION): ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# Visit the **"Solutions"** tab on LeetCode for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# ### **Example Answer (for "Palindrome Number"):**
#
# I reviewed the top solution under the LeetCode “Solutions” tab and one post on Stack Overflow:
# https://stackoverflow.com/questions/17129222/how-to-check-if-a-number-is-palindrome-in-python
#
# I learned that I can reverse the integer using a loop with modulo and division instead of converting it to a string. Using this idea, I tried writing a function that reverses the number and compares it to the original.

# %%
# Your draft code here (does not need to be fully correct)

# Griffin Wade-Salay (20260208)

# I came up with this solution by myself but have not figured out how to remove alphanumeric characters - this will be figured out by the next step (final code). I just
# wanted to get a rough code here with the framework of the solution. As a result, this code does not work 100% correctly.


def valid_palindrome(s: str) -> bool:
  valid_length = range(2, 2*(10**5) + 1)
  original_string = s

  if len(s) not in valid_length:
    raise ValueError("Please input a string of proper length (2 to 2*10^5).")

  reverse_string = original_string[::-1]

  if original_string == "":
    print(f"Output: true\n Explanation: s is an empty string "" after removing non-alphanumeric characters. Since an empty string reads the same forward and backward, it is a palindrome.")
    return True
  elif reverse_string == original_string:
    print(f"Output: true\n Explanation: {original_string} is a palindrome.")
    return True
  else:
    print(f"Output: false\nExplanation: {original_string} is not a palindrome.")
    return False

input_string = input("Please input characters to see if they constitute a palindrome.")
valid_palindrome(input_string)
# Out:
# Please input characters to see if they constitute a palindrome.""
# Output: true
#  Explanation: "" is a palindrome.
# True

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
# Final Code | Griffin Wade-Salay (20260208)
# Leetcode answers were used to help me figure out how to format the removal of potential non-alphanumeric characters in the input string.
# Specifically, Leetcode answers pointed me to use isalnum() which checks if the string contains only alphanumeric characters. By creating an empty string
# and appending it with all the alphanumeric characters present in the input string, a new string only consisting of alphanumeric characters can be reversed and
# tested. AI was only used in this step to figure out how to better deal with the empty string case (using if not as opposed to == "") and how to return multiple values
# to better format the printing to the user outside of the function.

def valid_palindrome(s: str) -> bool:  #defining the function - should accept a string and a boolean output
  valid_length = range(2, 2*(10**5) + 1)  #constraint on input string length
  edited_string = ""  #empty string which will be added with alphanumerical characters from the input string

  if len(s) not in valid_length:
    raise ValueError("Please input a string of proper length (2 to 2*10^5).")  #constraint check

  for i in s:
    if i.isalnum():
      edited_string += i.lower()   #adding the alphanumerical characters from the input to the empty string

  if not edited_string:
    return True, edited_string, "empty"  #case if input is a blank string

  reverse_string = edited_string[::-1]  #reversing the input string

  if reverse_string == edited_string:
    return True, edited_string, "palindrome"  #true case
  else:
    return False, edited_string, "not palindrome"  #false case

input_string = input("Please input characters to see if they constitute a palindrome.")
valid_palindrome(input_string)
result, cleaned, reason = valid_palindrome(input_string)   #assigning the returns

if reason == "empty":
  print(f"Output: true\nExplanation: s is an empty string \"\" after removing non-alphanumeric characters. Since an empty string reads the same forward and backward, it is a palindrome.")
elif result == True:
  print(f"Output: true\nExplanation: {cleaned} is a palindrome.")
else:
  print(f"Output: false\nExplanation: {cleaned} is not a palindrome.")   #print messages based on the potential outputs/returns
# Out:
# Please input characters to see if they constitute a palindrome.';';';
# Output: true
# Explanation: s is an empty string "" after removing non-alphanumeric characters. Since an empty string reads the same forward and backward, it is a palindrome.

# %% [markdown]
# Add the screenshot of output for all the test cases from your working solutions.

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: Added the part that checked for non-alphanumeric characters and removed them if they existed. Also cleaned up the string by making it lowercase.

# Draft code - This didn't exist in the draft code.

# Fixed version - This creates an empty string and adds all the alphanumeric characters from the input string to it. This new string is used going forward in the
# program and thus eliminates any non-alphanumeric characters.

edited_string = ""
for i in s:
  if i.isalnum():
    edited_string += i.lower()

if not edited_string:
  return True, edited_string, "empty"

# %%
# Fix 2: Better implemented the printing of the messages (whether it was a palindrome or not) by adding more returns and the print statements outside of the function.

# Draft version: Printing within the function

if original_string == "":
  print(f"Output: true\n Explanation: s is an empty string "" after removing non-alphanumeric characters. Since an empty string reads the same forward and backward, it is a palindrome.")
  return True
elif reverse_string == original_string:
  print(f"Output: true\n Explanation: {original_string} is a palindrome.")
  return True
else:
  print(f"Output: false\nExplanation: {original_string} is not a palindrome.")
  return False

# Fixed version: Returned three outputs and printed them outside of the function.

if not edited_string:
  return True, edited_string, "empty"
if reverse_string == edited_string:
  return True, edited_string, "palindrome"
else:
  return False, edited_string, "not palindrome"

result, cleaned, reason = valid_palindrome(input_string)

if reason == "empty":
  print(f"Output: true\nExplanation: s is an empty string \"\" after removing non-alphanumeric characters. Since an empty string reads the same forward and backward, it is a palindrome.")
elif result == True:
  print(f"Output: true\nExplanation: {cleaned} is a palindrome.")
else:
  print(f"Output: false\nExplanation: {cleaned} is not a palindrome.")

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# 1. I wrote the bones of this code myself as it wasn't overly difficult to understand what needed to be done. My outline was broadly correct but needed some tweaking.
#
# 2. AI (ChatGPT) was helpful for understanding where messages should be printed and when there is a more complex set of logic, it is best to return the necessary results and print them outside the function.
#
# 3. Leetcode answers were helpful for determining how to deal with the alphanumerical (or rather, non-alphanumerical character deletion) aspect of the problem. It was useful to see how I could deal with it by creating an empty string and adding to it all the alphanumerical values of the input string.

# %% [markdown]
# 1. Your Name: Griffin Wade-Salay
# 2. Section: Lecture - 2648
# 3. ID: 20260208
# 4. Github Link of this notebook:
# 5. Chat/ (Saved Chat in a shared Document link) https://1drv.ms/w/c/54a9996ef46400b3/EZTw3jv6nuZKr7GUKgwjEMcB2U-xoEjI5CAuPfdUQyfu6w?e=bHSYr8

# %% [markdown]
# # **The most important part of writing code is not the code itself, but the thinking that leads to it. Thank You**
